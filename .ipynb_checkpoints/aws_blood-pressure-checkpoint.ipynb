# %%
import boto3
import pandas as pd

# %%
# function to get tables and forms from image (aws textract)
def analyze_file(
             feature_types = ['TABLES','FORMS'], *, document_file_name=None, document_bytes=None):
        """
        Detects text and additional elements, such as forms or tables, in a local image
        file or from in-memory byte data.
        The image must be in PNG or JPG format.

        :param feature_types: The types of additional document features to detect.
        :param document_file_name: The name of a document image file.
        :param document_bytes: In-memory byte data of a document image.
        :return: The response from Amazon Textract, including a list of blocks
                 that describe elements detected in the image.
        """
        if document_file_name is not None:
            with open(document_file_name, 'rb') as document_file:
                document_bytes = document_file.read()
        try:
            response = aws_textract.analyze_document(
                Document={'Bytes': document_bytes}, FeatureTypes=feature_types)
#             logger.info(
#                 "Detected %s blocks.", len(response['Blocks']))
        except Exception as e:
            print("Exception -->> ",e)
        else:
            return response

# %%
# aws textrect
def extract_text_from_file(_file):

#     file = request.files.get(_file)
#     binaryFile = file.read()
#     binaryFile = _file
#     bin_data = open(_file, 'rb').read()
#     binaryFile = codecs.encode(bin_data, "hex_codec")
#     response = aws_textract.detect_document_text(
#         Document={
#             'Bytes': binaryFile
#         }
#     )
    with open(_file, "rb") as document:
        response = aws_textract.detect_document_text(
        Document={
            'Bytes': document.read(),
                }
            )
            

    extractedText = ""

    for block in response['Blocks']:
        if block["BlockType"] == "LINE":
            # print('\033[94m' + item["Text"] + '\033[0m')
            extractedText = extractedText+block["Text"]+" "

    responseJson = {

        "text": extractedText
    }
#     print(responseJson)
    return responseJson

# %% [markdown]
# # Calling AWS Textract

# %%
# comprehend client
aws_comprehend = boto3.client(service_name='comprehendmedical', region_name='us-east-2',aws_access_key_id = 'AKIAYO7JKT7XVYUKUWFN'
,aws_secret_access_key = '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')
# textrect client
aws_textract = boto3.client('textract',region_name='us-east-2')


image_path = './blood_presssure/bp6.jpeg'
# call aws textrect
# responseJson = extract_text_from_file(image_path)
responseJson = analyze_file(document_file_name=image_path)
responseJson
# Out:
# {'DocumentMetadata': {'Pages': 1},
#  'Blocks': [{'BlockType': 'PAGE',
#    'Geometry': {'BoundingBox': {'Width': 1.0,
#      'Height': 1.0,
#      'Left': 0.0,
#      'Top': 0.0},
#     'Polygon': [{'X': 1.1804675992898537e-16, 'Y': 0.0},
#      {'X': 1.0, 'Y': 1.270479408314404e-16},
#      {'X': 1.0, 'Y': 1.0},
#      {'X': 0.0, 'Y': 1.0}]},
#    'Id': '92603cbc-0245-4759-8959-dd6df38e3190',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['945e672b-bcf4-4beb-b773-0017cae38059',
#       '2c138d29-adcb-415f-b354-25444f6f4931',
#       '1888013d-5c0d-41bf-9208-fc280ba1ef13',
#       'e15c3ed3-ed2c-4a82-b424-0cc29bc7129d',
#       '87fd3e1b-06a8-41f0-8a62-7050b00d72ea',
#       'eda4b61f-f159-4d22-a00d-ab9e90fa733f',
#       '9b8d5cfc-f89b-41be-9c10-8cd6ef888b27',
#       'b3d84598-15f6-4f6d-9852-1bb5182c6df5',
#       '9aaf1268-252a-43d8-b344-39cd65129e59',
#       'b825917c-1677-43b8-8570-824fb2d47431',
#       '154f8c7f-5187-4ca5-a86d-0ae6c1eb2c6f',
#       '98a2108d-42dc-4a8f-91f5-f67aaf0c6ef3',
#       '2b07522b-57f7-4656-b5c3-7ec5b5c56788',
#       '2f95242a-ac87-4650-b40a-cfb84e951dd1',
#       'bc8ebca2-960d-4664-861b-a1e2dc9c1b16',
#       'f250201d-fe43-4763-9502-811a69d2cd45',
#       '4bde709c-5bd6-4ce2-a1c4-4aadfd0bc0a2']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.93619537353516,
#    'Text': 'metene',
#    'Geometry': {'BoundingBox': {'Width': 0.22537553310394287,
#      'Height': 0.04807797446846962,
#      'Left': 0.36537984013557434,
#      'Top': 0.038288358598947525},
#     'Polygon': [{'X': 0.36537984013557434, 'Y': 0.038288358598947525},
#      {'X': 0.5907553434371948, 'Y': 0.038288358598947525},
#      {'X': 0.5907553434371948, 'Y': 0.08636633306741714},
#      {'X': 0.36537984013557434, 'Y': 0.08636633306741714}]},
#    'Id': '945e672b-bcf4-4beb-b773-0017cae38059',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['28dcc232-8885-453a-a4a8-943e9eae1eb6']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 98.12898254394531,
#    'Text': 'A',
#    'Geometry': {'BoundingBox': {'Width': 0.017703454941511154,
#      'Height': 0.019323794171214104,
#      'Left': 0.630413293838501,
#      'Top': 0.14137902855873108},
#     'Polygon': [{'X': 0.630413293838501, 'Y': 0.14137902855873108},
#      {'X': 0.6481167078018188, 'Y': 0.14137902855873108},
#      {'X': 0.6481167078018188, 'Y': 0.16070282459259033},
#      {'X': 0.630413293838501, 'Y': 0.16070282459259033}]},
#    'Id': '2c138d29-adcb-415f-b354-25444f6f4931',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['b565990f-2411-4ea0-953a-38485855ee97']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.74908447265625,
#    'Text': 'Severe',
#    'Geometry': {'BoundingBox': {'Width': 0.08009079843759537,
#      'Height': 0.021548744291067123,
#      'Left': 0.170066237449646,
#      'Top': 0.16851909458637238},
#     'Polygon': [{'X': 0.170066237449646, 'Y': 0.16851909458637238},
#      {'X': 0.25015702843666077, 'Y': 0.16851909458637238},
#      {'X': 0.25015702843666077, 'Y': 0.1900678426027298},
#      {'X': 0.170066237449646, 'Y': 0.1900678426027298}]},
#    'Id': '1888013d-5c0d-41bf-9208-fc280ba1ef13',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['110df330-bcc7-4f97-91dc-e0b265956c25']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 94.36434173583984,
#    'Text': 'SYS',
#    'Geometry': {'BoundingBox': {'Width': 0.09223785996437073,
#      'Height': 0.03489493206143379,
#      'Left': 0.6915143132209778,
#      'Top': 0.15831539034843445},
#     'Polygon': [{'X': 0.6915143132209778, 'Y': 0.15831539034843445},
#      {'X': 0.7837522029876709, 'Y': 0.15831539034843445},
#      {'X': 0.7837522029876709, 'Y': 0.19321033358573914},
#      {'X': 0.6915143132209778, 'Y': 0.19321033358573914}]},
#    'Id': 'e15c3ed3-ed2c-4a82-b424-0cc29bc7129d',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['f97743b6-3bfe-4fb1-8425-5e7786d82ad2']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.7386245727539,
#    'Text': 'mmHg',
#    'Geometry': {'BoundingBox': {'Width': 0.061089497059583664,
#      'Height': 0.022296791896224022,
#      'Left': 0.7010164856910706,
#      'Top': 0.20141907036304474},
#     'Polygon': [{'X': 0.7010164856910706, 'Y': 0.20141907036304474},
#      {'X': 0.7621060013771057, 'Y': 0.20141907036304474},
#      {'X': 0.7621060013771057, 'Y': 0.2237158715724945},
#      {'X': 0.7010164856910706, 'Y': 0.2237158715724945}]},
#    'Id': '87fd3e1b-06a8-41f0-8a62-7050b00d72ea',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['7b72d145-8497-4c85-910b-4835c606966b']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.40277099609375,
#    'Text': 'Moderate',
#    'Geometry': {'BoundingBox': {'Width': 0.10618007928133011,
#      'Height': 0.02154942974448204,
#      'Left': 0.1430608630180359,
#      'Top': 0.24237261712551117},
#     'Polygon': [{'X': 0.1430608630180359, 'Y': 0.24237261712551117},
#      {'X': 0.2492409348487854, 'Y': 0.24237261712551117},
#      {'X': 0.2492409348487854, 'Y': 0.2639220356941223},
#      {'X': 0.1430608630180359, 'Y': 0.2639220356941223}]},
#    'Id': 'eda4b61f-f159-4d22-a00d-ab9e90fa733f',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['4d059750-283e-49fc-bb03-9020f4eacb98']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.8464584350586,
#    'Text': 'Mild',
#    'Geometry': {'BoundingBox': {'Width': 0.04535982385277748,
#      'Height': 0.021506257355213165,
#      'Left': 0.20414432883262634,
#      'Top': 0.31348496675491333},
#     'Polygon': [{'X': 0.20414432883262634, 'Y': 0.31348496675491333},
#      {'X': 0.24950414896011353, 'Y': 0.31348496675491333},
#      {'X': 0.24950414896011353, 'Y': 0.3349912166595459},
#      {'X': 0.20414432883262634, 'Y': 0.3349912166595459}]},
#    'Id': '9b8d5cfc-f89b-41be-9c10-8cd6ef888b27',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['f29649d1-3b1f-4de0-bbba-015d9768a9e9']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.87863159179688,
#    'Text': 'DIA',
#    'Geometry': {'BoundingBox': {'Width': 0.06847730278968811,
#      'Height': 0.034172423183918,
#      'Left': 0.7025203108787537,
#      'Top': 0.3332781195640564},
#     'Polygon': [{'X': 0.7025203108787537, 'Y': 0.3332781195640564},
#      {'X': 0.7709975838661194, 'Y': 0.3332781195640564},
#      {'X': 0.7709975838661194, 'Y': 0.3674505650997162},
#      {'X': 0.7025203108787537, 'Y': 0.3674505650997162}]},
#    'Id': 'b3d84598-15f6-4f6d-9852-1bb5182c6df5',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['b0cdb04b-7e5d-4b37-b679-2d74b8456552']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 94.11527252197266,
#    'Text': 'mmHg',
#    'Geometry': {'BoundingBox': {'Width': 0.06042401120066643,
#      'Height': 0.022300217300653458,
#      'Left': 0.7012672424316406,
#      'Top': 0.3754754364490509},
#     'Polygon': [{'X': 0.7012672424316406, 'Y': 0.3754754364490509},
#      {'X': 0.7616912722587585, 'Y': 0.3754754364490509},
#      {'X': 0.7616912722587585, 'Y': 0.39777565002441406},
#      {'X': 0.7012672424316406, 'Y': 0.39777565002441406}]},
#    'Id': '9aaf1268-252a-43d8-b344-39cd65129e59',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['5aeefa1a-2f4e-4296-8888-cc624e31bfb7']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99
']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.83258056640625,
#    'Text': 'SET',
#    'Geometry': {'BoundingBox': {'Width': 0.05611314997076988,
#      'Height': 0.024621106684207916,
#      'Left': 0.2369622141122818,
#      'Top': 0.7892972230911255},
#     'Polygon': [{'X': 0.2369622141122818, 'Y': 0.7892972230911255},
#      {'X': 0.2930753529071808, 'Y': 0.7892972230911255},
#      {'X': 0.2930753529071808, 'Y': 0.8139183521270752},
#      {'X': 0.2369622141122818, 'Y': 0.8139183521270752}]},
#    'Id': 'bc8ebca2-960d-4664-861b-a1e2dc9c1b16',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['67a05d52-6efb-4a9c-93a4-03d11455e01f']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.74004364013672,
#    'Text': 'MEM',
#    'Geometry': {'BoundingBox': {'Width': 0.06554929167032242,
#      'Height': 0.024258367717266083,
#      'Left': 0.6715832352638245,
#      'Top': 0.7896959781646729},
#     'Polygon': [{'X': 0.6715832352638245, 'Y': 0.7896959781646729},
#      {'X': 0.7371325492858887, 'Y': 0.7896959781646729},
#      {'X': 0.7371325492858887, 'Y': 0.8139543533325195},
#      {'X': 0.6715832352638245, 'Y': 0.8139543533325195}]},
#    'Id': 'f250201d-fe43-4763-9502-811a69d2cd45',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['58352407-45a1-498f-8dbf-3779ef632824']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.92059326171875,
#    'Text': 'STOP',
#    'Geometry': {'BoundingBox': {'Width': 0.07718886435031891,
#      'Height': 0.024984942749142647,
#      'Left': 0.44498997926712036,
#      'Top': 0.813351035118103},
#     'Polygon': [{'X': 0.44498997926712036, 'Y': 0.813351035118103},
#      {'X': 0.5221788287162781, 'Y': 0.813351035118103},
#      {'X': 0.5221788287162781, 'Y': 0.8383359909057617},
#      {'X': 0.44498997926712036, 'Y': 0.8383359909057617}]},
#    'Id': '4bde709c-5bd6-4ce2-a1c4-4aadfd0bc0a2',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['97692d31-3154-430d-ac33-bfc6e9412ac5']}]},
#   {'BlockType': 'WORD',
#    'Confidence': 99.93619537353516,
#    'Text': 'metene',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.22537553310394287,
#      'Height': 0.04807797446846962,
#      'Left': 0.36537984013557434,
#      'Top': 0.038288358598947525},
#     'Polygon': [{'X': 0.36537984013557434, 'Y': 0.038288358598947525},
#      {'X': 0.5907553434371948, 'Y': 0.038288358598947525},
#      {'X': 0.5907553434371948, 'Y': 0.08636633306741714},
#      {'X': 0.36537984013557434, 'Y': 0.08636633306741714}]},
#    'Id': '28dcc232-8885-453a-a4a8-943e9eae1eb6'},
#   {'BlockType': 'WORD',
#    'Confidence': 98.12898254394531,
#    'Text': 'A',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.017703454941511154,
#      'Height': 0.019323794171214104,
#      'Left': 0.630413293838501,
#      'Top': 0.14137902855873108},
#     'Polygon': [{'X': 0.630413293838501, 'Y': 0.14137902855873108},
#      {'X': 0.6481167078018188, 'Y': 0.14137902855873108},
#      {'X': 0.6481167078018188, 'Y': 0.16070282459259033},
#      {'X': 0.630413293838501, 'Y': 0.16070282459259033}]},
#    'Id': 'b565990f-2411-4ea0-953a-38485855ee97'},
#   {'BlockType': 'WORD',
#    'Confidence': 99.74908447265625,
#    'Text': 'Severe',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.08009079843759537,
#      'Height': 0.021548744291067123,
#      'Left': 0.170066237449646,
#      'Top': 0.16851909458637238},
#     'Polygon': [{'X': 0.170066237449646, 'Y': 0.16851909458637238},
#      {'X': 0.25015702843666077, 'Y': 0.16851909458637238},
#      {'X': 0.25015702843666077, 'Y': 0.1900678426027298},
#      {'X': 0.170066237449646, 'Y': 0.1900678426027298}]},
#    'Id': '110df330-bcc7-4f97-91dc-e0b265956c25'},
#   {'BlockType': 'WORD',
#    'Confidence': 94.36434173583984,
#    'Text': 'SYS',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0
},
#   {'BlockType': 'WORD',
#    'Confidence': 99.74004364013672,
#    'Text': 'MEM',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.06554929167032242,
#      'Height': 0.024258367717266083,
#      'Left': 0.6715832352638245,
#      'Top': 0.7896959781646729},
#     'Polygon': [{'X': 0.6715832352638245, 'Y': 0.7896959781646729},
#      {'X': 0.7371325492858887, 'Y': 0.7896959781646729},
#      {'X': 0.7371325492858887, 'Y': 0.8139543533325195},
#      {'X': 0.6715832352638245, 'Y': 0.8139543533325195}]},
#    'Id': '58352407-45a1-498f-8dbf-3779ef632824'},
#   {'BlockType': 'WORD',
#    'Confidence': 99.92059326171875,
#    'Text': 'STOP',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.07718886435031891,
#      'Height': 0.024984942749142647,
#      'Left': 0.44498997926712036,
#      'Top': 0.813351035118103},
#     'Polygon': [{'X': 0.44498997926712036, 'Y': 0.813351035118103},
#      {'X': 0.5221788287162781, 'Y': 0.813351035118103},
#      {'X': 0.5221788287162781, 'Y': 0.8383359909057617},
#      {'X': 0.44498997926712036, 'Y': 0.8383359909057617}]},
#    'Id': '97692d31-3154-430d-ac33-bfc6e9412ac5'}],
#  'AnalyzeDocumentModelVersion': '1.0',
#  'ResponseMetadata': {'RequestId': '2386add5-7ed8-4e72-b2d4-4e99737b6f19',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '2386add5-7ed8-4e72-b2d4-4e99737b6f19',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '18241',
#    'date': 'Thu, 10 Mar 2022 10:31:40 GMT'},
#   'RetryAttempts': 0}}

# %%
for blks in responseJson['Blocks']:
    print('Text : ', blks.get('Text'),' <------> Type : ',blks.get('TextType'))
#     break
# Out:
# Text :  None  <------> Type :  None
# Text :  metene  <------> Type :  None
# Text :  A  <------> Type :  None
# Text :  Severe  <------> Type :  None
# Text :  SYS  <------> Type :  None
# Text :  mmHg  <------> Type :  None
# Text :  Moderate  <------> Type :  None
# Text :  Mild  <------> Type :  None
# Text :  DIA  <------> Type :  None
# Text :  mmHg  <------> Type :  None
# Text :  Normal  <------> Type :  None
# Text :  PUL  <------> Type :  None
# Text :  /min.  <------> Type :  None
# Text :  0:02  <------> Type :  None
# Text :  START  <------> Type :  None
# Text :  SET  <------> Type :  None
# Text :  MEM  <------> Type :  None
# Text :  STOP  <------> Type :  None
# Text :  metene  <------> Type :  PRINTED
# Text :  A  <------> Type :  PRINTED
# Text :  Severe  <------> Type :  PRINTED
# Text :  SYS  <------> Type :  PRINTED
# Text :  mmHg  <------> Type :  PRINTED
# Text :  Moderate  <------> Type :  PRINTED
# Text :  Mild  <------> Type :  PRINTED
# Text :  DIA  <------> Type :  PRINTED
# Text :  mmHg  <------> Type :  PRINTED
# Text :  Normal  <------> Type :  PRINTED
# Text :  PUL  <------> Type :  PRINTED
# Text :  /min.  <------> Type :  PRINTED
# Text :  0:02  <------> Type :  PRINTED
# Text :  START  <------> Type :  PRINTED
# Text :  SET  <------> Type :  PRINTED
# Text :  MEM  <------> Type :  PRINTED
# Text :  STOP  <------> Type :  PRINTED

# %% [markdown]
# # Pre processing after calling textract for tables

# %%
def map_blocks(blocks, block_type):
    return {
        block['Id']: block
        for block in blocks
        if block['BlockType'] == block_type
    }

def get_children_ids(block):
    for rels in block.get('Relationships', []):
        if rels['Type'] == 'CHILD':
            yield from rels['Ids']
            

def get_tables(responseJson):
    blocks = responseJson['Blocks']
    tables = map_blocks(blocks, 'TABLE')
    cells = map_blocks(blocks, 'CELL')
    words = map_blocks(blocks, 'WORD')
    selections = map_blocks(blocks, 'SELECTION_ELEMENT')

    dataframes = []

    for table in tables.values():

        # Determine all the cells that belong to this table
        table_cells = [cells[cell_id] for cell_id in get_children_ids(table)]

        # Determine the table's number of rows and columns
        n_rows = max(cell['RowIndex'] for cell in table_cells)
        n_cols = max(cell['ColumnIndex'] for cell in table_cells)
        content = [[None for _ in range(n_cols)] for _ in range(n_rows)]

        # Fill in each cell
        for cell in table_cells:
            cell_contents = [
                words[child_id]['Text']
                if child_id in words
                else selections[child_id]['SelectionStatus']
                for child_id in get_children_ids(cell)
            ]
            i = cell['RowIndex'] - 1
            j = cell['ColumnIndex'] - 1
            content[i][j] = ' '.join(cell_contents)

        # We assume that the first row corresponds to the column names
        dataframe = pd.DataFrame(content[1:], columns=content[0])
        dataframes.append(dataframe)
    return dataframes

def dataframes_to_strings(table_dataframes):
    list_of_tables_str = []
    for tb_df in table_dataframes:
        table_str = ''
        for row in tb_df.iterrows():
            table_str = table_str + '\n' +'\n'.join(row[-1].to_string().split())
        list_of_tables_str.append(table_str)    
    return list_of_tables_str

# get tables
table_dataframes = get_tables(responseJson)
table_dataframes_final = table_dataframes.copy()
tables_strs_list = dataframes_to_strings(table_dataframes)

# %% [markdown]
# # Calling AWS Comprehend

# %%
comprehend_results = []
for table_str in tables_strs_list:
    # call aws comprehend
    result = aws_comprehend.detect_entities_v2(Text= table_str)
    comprehend_results.append(result)
#     entities = result['Entities'];
#     for entity in entities:
#         print('Entity', entity)
#         print('\n\n')

# %%
# check if comprehend result should be return or textract
table_should_not_in_comprehend = []
comprehend_results_final = comprehend_results.copy()
for ind, comprehend_table in enumerate(comprehend_results):
    cat_count = 0
    should_not = 1
    for entities in comprehend_table['Entities']:
        if entities['Category'] == 'PROTECTED_HEALTH_INFORMATION':
            cat_count+=1
            
    print(cat_count/len(comprehend_table['Entities']))
    print('====')
    if cat_count/len(comprehend_table['Entities']) > 0.8:
        should_not = 0
        comprehend_results_final.remove(comprehend_table)
    else:
        table_dataframes_final.remove(table_dataframes_final[ind])
    
    table_should_not_in_comprehend.append(should_not) # 0 => should not, 1 => should be

# %%
len(comprehend_results_final)

# %% [markdown]
# # Get relevent data from comprehend result

# %%
# comprehend_results_final[0]['Entities'][5]['Attributes'][0]['Type']
# comprehend_results_final[0]['Entities'][5]['Attributes'][0]['Text']


final_list_of_entities_dict = []
for comprehend_table_data in comprehend_results_final:
    comprehend_entities = comprehend_table_data.get('Entities')
    
    if comprehend_entities:
        entity_dict = {}
        for comprehend_entity in comprehend_entities:
            comp_entity = comprehend_entity.get('Category')
            if (comp_entity != 'PROTECTED_HEALTH_INFORMATION') and (comp_entity != None):
#                 print(comprehend_entity['Category'])
                parent_text = comprehend_entity.get('Text')
                parent_type = comprehend_entity.get('Type')
#                 print('\np_Type : ',parent_type,'  p_Text : ',parent_text)
                entity_dict[parent_text] = []
                entity_attributes = comprehend_entity.get('Attributes')
                if entity_attributes:
                    for entity_attribute in entity_attributes:
                        att_type = entity_attribute.get('Type')
                        att_text = entity_attribute.get('Text')
#                         print('type : ',att_type,'  text : ',att_text)
                        entity_dict[parent_text].append({att_type:att_text})
#         entity_dict[]
#         print(entity_dict)
        final_list_of_entities_dict.append(entity_dict)
#         break

# %%
final_list_of_entities_dict[0]

# %% [markdown]
# # Convert texract tables to dict (json)

# %%
table_dataframes[0].columns = table_dataframes[0].iloc[0] 

testing = table_dataframes[0][1:]
testing
# table_dataframes[0].head()
# table_dataframes[0]

testing.to_dict('records')

# %%
df = table_dataframes[1]
df2 = dict(zip(df[df.columns[0]],df[df.columns[1]].values.tolist()))
df2[df.columns[0]]=df.columns[1]

df2

# %%
df = table_dataframes[2]
df3 = dict(zip(df[df.columns[0]],df[df.columns[1]].values.tolist()))
df3[df.columns[0]]=df.columns[1]
df3

# %%
my_json = {}
my_json['patient_details'] = df3

my_json['report_details'] = df2

my_json['test_details'] = testing.to_dict('records')

# %%
import json
json.dumps(my_json)

# %%
my_json

# %%
from flask import Flask, request 
import boto3
app = Flask(__name__)
from werkzeug.utils import secure_filename

s3 = boto3.client(
        "s3",
        region_name='us-east-2',
        aws_access_key_id="AKIAYO7JKT7XVYUKUWFN",
        aws_secret_access_key="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",)




BUCKET_NAME='texractnew'
print(s3)


@app.route('/upload',methods=['post'])
def upload():
    if request.method == 'POST':
        files_add = request.files.getlist("files")
        print(files_add)
        for file in files_add:
            if file:
                    filename = secure_filename(file.filename)
                    file.save(filename)
#                     import boto3

                    # Document
                    documentName = filename

                    # Amazon Textract client
                    textract = boto3.client('textract')

                    # Call Amazon Textract
                    with open(documentName, "rb") as document:
                        response = textract.detect_document_text(
                        Document={
                            'Bytes': document.read(),
                                }
                            )

                    #print(response)

                    # Print text
                    print("\nText\n========")
                    text = ""
                    for item in response["Blocks"]:
                        if item["BlockType"] == "LINE":
                            print ('\033[94m' +  item["Text"] + '\033[0m')
                            text = text + " " + item["Text"]

                    # Amazon Comprehend client
                    comprehend = boto3.client('comprehendmedical')

                    # Detect medical entities
                    entities =  comprehend.detect_entities(Text=text)
                    print("\nMedical Entities\n========")
                    for entity in entities["Entities"]:
                        print("- {}".format(entity["Text"]))
                        print ("   Type: {}".format(entity["Type"]))
                        print ("   Category: {}".format(entity["Category"]))
                        if(entity["Traits"]):
                            print("   Traits:")
                            for trait in entity["Traits"]:
                                print ("    - {}".format(trait["Name"]))
                                print("\n")
                               
                               
                    
#                     s3.upload_file(
#                             Bucket = BUCKET_NAME,
#                                 Filename=filename,
#                                 Key = filename
#                              )
                             
                    return (entities)

if __name__ == "__main__":
    
    app.run(debug=True)
